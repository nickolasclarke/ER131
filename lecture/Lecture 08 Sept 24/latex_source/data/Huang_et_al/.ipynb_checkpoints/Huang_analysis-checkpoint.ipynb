# %% [markdown]
# This notebook works with data from the Huang et al paper in the same directory.  Hospital visits for respiratory problems, for cardiac problems, and pollution data.

# %%
import pandas as pd
import numpy as np

# %%
seoul = pd.read_csv('data_20170517.csv')

# %%
seoul.head()
# Out:
#          date      pm2.5       pm10        OC        EC        NO3       SO42  \
# 0  2010-04-17  30.125000  54.560589       NaN       NaN  15.387663  11.180539
# 1  2010-04-18  33.791667  65.262147       NaN       NaN        NaN        NaN
# 2  2010-04-19  32.125000  63.370968       NaN       NaN        NaN        NaN
# 3  2010-04-20  31.500000  61.098737       NaN       NaN        NaN        NaN
# 4  2010-04-21  18.916667  36.457569  5.311228  1.157107   9.452813   7.429105
#
#    NH4  meantemp  mintemp   ...    circ  circ_A  circ_B  circ_M  circ_F  resp  \
# 0  NaN       7.6      4.0   ...     147      76      71      87      60   770
# 1  NaN      12.0      6.2   ...     117      64      53      62      55   675
# 2  NaN      14.7     12.7   ...     147      89      58      91      56   436
# 3  NaN      16.8     13.3   ...     146      68      78      84      62   395
# 4  NaN      14.1     10.7   ...     131      65      66      76      55   367
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(seoul['circ_F'], seoul['circ_M'], c = seoul['meantemp'], cmap = 'viridis')
cbar = plt.colorbar();  # show color scale
cbar.set_label('temperature (C)')
plt.xlabel('PM2.5 concentrations (micrograms / cubic meter)')
plt.ylabel('Daily ER visits for cardiovascular disease')
plt.title('')
# Out:
# Text(0.5,1,'')
