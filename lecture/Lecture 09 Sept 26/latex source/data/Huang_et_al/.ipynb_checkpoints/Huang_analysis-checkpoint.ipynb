# %% [markdown]
# This notebook works with data from the Huang et al paper in the same directory.  Hospital visits for respiratory problems, for cardiac problems, and pollution data.

# %%
import pandas as pd
import numpy as np

# %%
seoul = pd.read_csv('data_20170517.csv')

# %%
seoul.tail()
# Out:
#             date      pm2.5       pm10  OC  EC  NO3  SO42  NH4  meantemp  \
# 1115  2013-05-06  28.958333  50.086772 NaN NaN  NaN   NaN  NaN      14.6
# 1116  2013-05-07  43.500000  74.887593 NaN NaN  NaN   NaN  NaN      18.7
# 1117  2013-05-08  34.708333  64.412076 NaN NaN  NaN   NaN  NaN      19.4
# 1118  2013-05-09  37.625000  68.458599 NaN NaN  NaN   NaN  NaN      18.1
# 1119  2013-05-10  20.428571  32.752128 NaN NaN  NaN   NaN  NaN      14.0
#
#       mintemp   ...    circ  circ_A  circ_B  circ_M  circ_F  resp  resp_A  \
# 1115      7.9   ...     133      64      69      75      58   316     273
# 1116     11.9   ...     150      72      78      80      70   325     279
# 1117     12.7   ...     139      74      65      77      62   336     289
# 1118     14.7   ...     132      72      60      81      51   362     326
# 1119     10.4   ...     148      75      73      72      76   420     370
#
#       resp_B resp_M  resp_F
# 1115      43    163     153
# ...

# %%
import matplotlib.pyplot as plt

# %%
sz = 35 # symbol size

# %%
plt.scatter(seoul['pm2.5'], seoul['circ'], s = sz)#, c = seoul['meantemp'], cmap = 'viridis', s = 5)
#cbar = plt.colorbar();  # show color scale
#cbar.set_label('temperature (C)')
#plt.xlabel('PM2.5 concentrations (micrograms / cubic meter)')
#plt.ylabel('Daily ER visits for cardiovascular disease')
#plt.title('Data from Korean Hospitals, 2010-2013')
SMALL_SIZE = 14
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)
plt.savefig('huang_pm25vcirc_notitle.pdf', format = 'pdf', dpi = 300, bbox_inches='tight')

# %%
plt.scatter(seoul['pm2.5'], seoul['circ'], s = sz)#, c = seoul['meantemp'], cmap = 'viridis', s = 5)
#cbar = plt.colorbar();  # show color scale
#cbar.set_label('temperature (C)')
plt.xlabel('PM2.5 concentrations (micrograms / cubic meter)')
plt.ylabel('Cardiovascular disease visits')
plt.title('Daily ER visits, Korean Hospitals, 2010-2013')

SMALL_SIZE = 14
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)
plt.savefig('huang_pm25vcirc.pdf', format = 'pdf', dpi = 300, bbox_inches='tight')

# %%
plt.scatter(seoul['pm2.5'], seoul['circ'], c = seoul['meantemp'], cmap = 'viridis', s = sz)
cbar = plt.colorbar();  # show color scale
cbar.set_label('temperature (C)')
plt.xlabel('PM2.5 concentrations (micrograms / cubic meter)')
plt.ylabel('Cardiovascular disease visits')
plt.title('Daily ER visits, Korean Hospitals, 2010-2013')

SMALL_SIZE = 14
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)

plt.savefig('huang_pm25vcirc_color.pdf', format = 'pdf', dpi = 300, bbox_inches='tight')

# %%
from numpy import random

# %%
np.random.seed(15)
x = np.random.randn(10)*7+ 20
#x = np.arange(5,30,2.5)
lolim = 300
hilim = 7500
vel = 300
ht = 500
y = -0.5*9.8*x**2 + vel*x + ht

# %%
plt.scatter(x,y, s = sz)

SMALL_SIZE = 14
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)
plt.ylim(lolim, hilim)

plt.savefig('projectile_notitle.pdf', format = 'pdf', dpi = 300, bbox_inches='tight')

# %%
plt.scatter(x,y, s = sz)
plt.title('Projectile motion')
plt.ylabel('Height (m)')
plt.xlabel('Time (s)')

x_more = np.arange(np.min(x), np.max(x), 0.01)
y_more = -0.5*9.8*x_more**2 + vel*x_more + ht

plt.plot(x_more,y_more,'-', c = 'r')

SMALL_SIZE = 14
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)
plt.ylim(lolim, hilim)

plt.savefig('projectile.pdf', format = 'pdf', dpi = 300, bbox_inches='tight')

# %%
eps = np.random.randn(10)*500
y = -0.5*9.8*x**2 + vel*x + ht + eps
plt.scatter(x,y, s = sz)
plt.title('Noisy projectile motion')
plt.ylabel('Height (m)')
plt.xlabel('Time (s)')

plt.plot(x_more,y_more,'-', c = 'r')

SMALL_SIZE = 14
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)
plt.ylim(lolim, hilim)

plt.savefig('projectile_noise.pdf', format = 'pdf', dpi = 300, bbox_inches='tight')

# %%
import seaborn as sns

# %%
sns.regplot(seoul['pm2.5'], seoul['circ'], line_kws={'color': 'red'}, ci = None)#, c = seoul['meantemp'], cmap = 'viridis', s = 5)
#cbar = plt.colorbar();  # show color scale
#cbar.set_label('temperature (C)')
plt.xlabel('PM2.5 concentrations (micrograms / cubic meter)')
plt.ylabel('Cardiovascular disease visits')
plt.title('Daily ER visits, Korean Hospitals, 2010-2013')

SMALL_SIZE = 14
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)
plt.savefig('huang_pm25vcirc_regplot.pdf', format = 'pdf', dpi = 300)

# %%
from sklearn import neighbors

# %%
pm25_array = np.array(seoul['pm2.5']).reshape(-1,1) # knn algorithm wants a NP array of this shape.

# %%
knn_reg = neighbors.KNeighborsRegressor(n_neighbors = 100, weights='uniform')
knn_reg.fit(pm25_array, seoul['circ'])

X_pred = np.arange(0,120,0.01).reshape(-1,1)
output = knn_reg.predict(X_pred) #use the model we just created to predict

sns.regplot(seoul['pm2.5'], seoul['circ'], line_kws={'color': 'red'}, ci = None)

plt.plot(X_pred, output,'-', c = 'y')

plt.xlabel('PM2.5 concentrations (micrograms / cubic meter)')
plt.ylabel('Cardiovascular disease visits')
plt.title('Daily ER visits, Korean Hospitals, 2010-2013')

SMALL_SIZE = 14
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)
plt.savefig('huang_pm25vcirc_knn.pdf', format = 'pdf', dpi = 300)
