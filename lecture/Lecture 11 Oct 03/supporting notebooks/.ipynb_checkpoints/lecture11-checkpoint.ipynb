# %% [markdown]
# ## Nonlinear Features
#
# October 3, 2019
#
# Duncan Callaway
#
# This notebook explores how adding nonlinear transformation of predictors improves (or doesn't) model fit.

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy import stats

# %%
#this will allow us to see all the columns of the data frame when we display it.
pd.set_option('display.max_columns', 150)

# %%
# we'll use these later in the notebook
novotny_features = ['WRF+DOMINO', 'Impervious_6000', 'Major_800', 'total_100', 'Major_100', 'Major_200', 'Elevation_truncated_km', 'Distance_to_coast_km', 'Population_800', 'total_800'];

# %%
df_all = pd.read_csv('BechleLUR_2006_allmodelbuildingdata.csv')

# %%
df_all.head()
# Out:
#             Monitor_ID State  Latitude  Longitude  Observed_NO2_ppb  \
# 0  04-013-0019-42602-1    AZ  33.48385 -112.14257         23.884706
# 1  04-013-3002-42602-6    AZ  33.45793 -112.04601         25.089886
# 2  04-013-3003-42602-1    AZ  33.47968 -111.91721         19.281969
# 3  04-013-3010-42602-1    AZ  33.46093 -112.11748         30.645138
# 4  04-013-4011-42602-1    AZ  33.37005 -112.62070         11.070412
#
#    Predicted_NO2_ppb  WRF+DOMINO  Distance_to_coast_km  \
# 0          20.986643   11.615223                 313.0
# 1          20.990096   11.472677                 323.8
# 2          18.088153    8.990372                 308.4
# 3          20.358009   11.919268                 309.0
# 4           8.549622    2.141366                 269.5
#
#    Elevation_truncated_km  Impervious_100  Impervious_200  Impervious_300  \
# 0                   0.304         59.4431         59.4715         59.4810
# 1                   0.304         72.0000         72.0000         72.0000
# 2                   0.304         53.0000         53.0000         52.7818
# 3                   0.304         61.3099         62.2828         62.6643
# 4                   0.293         12.0000         12.0000         11.5703
#
#    Impervious_400  Impervious_500  Impervious_600  Impervious_700  \
# 0         59.4572         59.3039         59.1636         59.0507
# 1         72.0000         71.9109         71.6594         71.4787
# 2         52.6609         52.7508         52.9035         53.1840
# 3         62.8645         62.9876         63.0707         63.1307
# 4         10.7575         10.0111          8.9894          8.2637
#
#    Impervious_800  Impervious_1000  Impervious_1200  Impervious_1500  \
# 0         58.9488          58.7941          58.9821          59.2879
# 1         71.4093          71.4899          71.6481          71.9319
# 2         53.5480          54.2690          54.9128          55.4105
# 3         63.1760          63.2921          63.9276          64.9895
# 4          7.7453           6.9656           6.3764           5.8273
#
#    Impervious_1800  Impervious_2000  Impervious_2500  Impervious_3000  \
# 0          59.8456          60.1169          60.1553          59.7722
# 1          71.8449          71.2728          69.4570          68.0373
# 2          55.5081          55.4734          55.3731          54.5066
# 3          65.5503          65.6761          65.4882          65.0786
# 4           5.4396           5.2452           4.8001           4.5851
#
#    Impervious_3500  Impervious_4000  Impervious_5000  Impervious_6000  \
# 0          59.5908          59.5556          59.2200          58.3484
# 1          66.6440          65.7764          63.4799          60.5909
# 2          52.6556          50.2736          45.2637          40.9808
# 3          64.5252          63.5507          61.0603          58.9640
# 4           4.6771           5.1123           5.4168           5.1086
#
#    Impervious_7000  Impervious_8000  Impervious_10000  Population_100  \
# 0          57.5475          56.3765           52.2642       3434.0000
# 1          59.0333          58.2535           55.1395       2715.9121
# 2          38.5957          37.9640           38.3574       1862.0000
# 2    8.85217   11.15662   14.69973    23.00265    34.76959    56.57990
# 3   10.98230   14.29600   17.57163    27.67279    48.64059    79.33741
# 4    2.14752    2.65432    3.18936     4.14743     5.03112     6.31225
#
#    total_1800  total_2000  total_2500  total_3000  total_3500  total_4000  \
# 0    93.35176   114.22691   173.17856   258.91709   357.23710   465.82199
# 1   135.07974   159.76601   228.59590   308.16510   402.84368   511.36713
# 2    88.11118   112.24936   176.53940   254.68526   342.30210   440.62762
# 3   110.01802   134.93770   203.91051   285.62512   384.67942   495.20557
# 4     7.57766     8.41213    10.49776    12.55789    18.63745    33.74815
#
#    total_5000  total_6000  total_7000  total_8000  total_10000  total_10500  \
# 0   726.61034  1034.94745  1388.35431  1788.38015   2637.91917   2862.73591
# 1   781.83358  1016.93143  1331.77774  1731.04787   2562.32948   2791.32295
# 2   616.14388   786.53539   997.10904  1254.14847   1965.43346   2157.42878
# 3   724.98695   991.11252  1272.67905  1599.66889   2449.51041   2660.60636
# 4    70.94735    86.59609   113.97290   149.29461    222.34687    244.41106
#
#    total_11000  total_11500  total_12000  total_12500  total_13000  \
# 0   3096.99468   3339.22952   3609.20650   3896.25748   4150.54739
# 1   3015.79024   3248.95785   3489.76919   3723.01595   3963.41655
# 2   2362.96458   2584.38952   2820.52494   3052.44507   3315.05126
# 3   2879.53599   3109.74604   3339.37790   3597.15279   3848.61451
# 4    269.54740    293.31410    320.37722    349.76462    386.03419
#
#    total_13500  total_14000
# 0   4396.96011   4651.18890
# 1   4196.37496   4459.57421
# 2   3607.37536   3921.12841
# 3   4125.08884   4427.95530
# 4    412.91888    441.52860

# %%
X = df_all.loc[:,['WRF+DOMINO']]
Y = df_all["Observed_NO2_ppb"]

# %%
plt.scatter(X,Y)
plt.xlabel('WRF+DOMINO')
plt.ylabel('Observed_NO2_ppb')
# Out:
# Text(0,0.5,'Observed_NO2_ppb')

# %%
X_const = sm.add_constant(X)
X_const.head()
# Out:
#    const  WRF+DOMINO
# 0    1.0   11.615223
# 1    1.0   11.472677
# 2    1.0    8.990372
# 3    1.0   11.919268
# 4    1.0    2.141366

# %%
est = sm.OLS(Y, X_const)
result_simple = est.fit()
result_simple.aic
# Out:
# 2079.9621899902477

# %% [markdown]
# Now let's try estimating a model with **all** the predictors embedded:

# %%
X_all = df_all.loc[:,'WRF+DOMINO':'total_14000']
X_all_const = sm.add_constant(X_all)
est_all = sm.OLS(Y, X_all_const)
result_all = est_all.fit()
result_all.aic
# Out:
# 1943.8860203123427

# %% [markdown]
# And now a model that is close to (but not exactly the same as) Novotny's

# %%
X_base = df_all[novotny_features]

X_base_const = sm.add_constant(X_base)
est_base = sm.OLS(Y, X_base_const)
results_base = est_base.fit()
results_base.aic
# Out:
# 1894.6813213241203

# %% [markdown]
# Let's call that the 'base' AIC.
#
# What if we add a nonlinear predictor?
#
# One of the things Novotny claims to be missing is traffic volume.  They use road density instead.
#
# What if we try adding a variable that is people per km of road?

# %%
to_add = pd.Series(df_all.loc[:,'Population_800'] / (df_all.loc[:,'total_800']))

# %%
# check for infs and nans:
print('infs: ', np.sum(np.isinf(to_add)))
print('NaNs: ', np.sum(np.isnan(to_add)))
# Out:
# infs:  3
# NaNs:  2

# %%
# let's fix
to_add.loc[np.isnan(to_add)] = 0
to_add.loc[np.isinf(to_add)] = 0

# %%
X_base_const_new = X_base_const
X_base_const_new['pop_per_road_800'] = to_add

est_base_popperroad = sm.OLS(Y, X_base_const_new)
results_base_popperroad = est_base_popperroad.fit()
results_base_popperroad.aic
# Out:
# 1891.588653941647

# %% [markdown]
# That's a small improvement.
#
# Novotny also don't include population in the model.  I tried a few versions of population -- linear to start.  But what about this one:  population^(1/4)

# %%
to_add = pd.Series(df_all.loc[:,'Population_800']**(0.25))

X_base_pop4root_const = X_base_const.assign(pop_4root = to_add.values)

est_base_pop4root = sm.OLS(Y, X_base_pop4root_const)
results_base_pop4root = est_base_pop4root.fit()
results_base_pop4root.aic
# Out:
# 1874.9162662822366

# %%
print(results_base_pop4root.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Observed_NO2_ppb   R-squared:                       0.795
# Model:                            OLS   Adj. R-squared:                  0.788
# Method:                 Least Squares   F-statistic:                     115.2
# Date:                Thu, 03 Oct 2019   Prob (F-statistic):          1.37e-114
# Time:                        09:26:27   Log-Likelihood:                -924.46
# No. Observations:                 369   AIC:                             1875.
# Df Residuals:                     356   BIC:                             1926.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      0.2714      0.620      0.438      0.662      -0.948       1.491
# WRF+DOMINO                 0.6639      0.043     15.580      0.000       0.580       0.748
# Impervious_6000            0.0329      0.017      1.969      0.050    4.73e-05       0.066
# Major_800                  0.2956      0.083      3.567      0.000       0.133       0.459
# total_100                  3.4981      1.184      2.956      0.003       1.170       5.826
# Major_100                 -6.0597      2.872     -2.110      0.036     -11.707      -0.412
# Major_200                  1.5916      0.921      1.728      0.085      -0.220       3.403
# Elevation_truncated_km    11.8105      1.693      6.974      0.000       8.480      15.141
# Distance_to_coast_km      -0.0007      0.000     -1.580      0.115      -0.001       0.000
# Population_800         -6.076e-05      0.000     -0.457      0.648      -0.000       0.000
# total_800                 -0.0218      0.043     -0.508      0.612      -0.106       0.063
# pop_per_road_800          -0.0001      0.003     -0.047      0.963      -0.005       0.005
# pop_4root                  0.8496      0.198      4.299      0.000       0.461       1.238
# ==============================================================================
# Omnibus:                       28.528   Durbin-Watson:                   1.351
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.759
# Skew:                           0.617   Prob(JB):                     1.72e-08
# Kurtosis:                       3.896   Cond. No.                     5.14e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.14e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Even better!
#
# Anything else the class wants to experiment with?

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
neigh = KNeighborsRegressor(n_neighbors=3)
neigh.fit(X_base_pop4root_const, Y)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#           weights='uniform')

# %% [markdown]
# `score` returns the R2:

# %%
neigh.score(X_base_pop4root_const, Y)
# Out:
# 0.6905422193950861

# %% [markdown]
# Really important note: here we are evaluating performance using the data -- not with test data.
#
# Especially for comparing across models, we MUST use an "unseen" test data set for evaluation.  This is coming next week.

# %% [markdown]
# **Question**: What happens if K=1?  What will R2 be?

# %%
neigh = KNeighborsRegressor(n_neighbors=1)
neigh.fit(X_base_pop4root_const, Y) 
neigh.score(X_base_pop4root_const, Y)
# Out:
# 1.0
